# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h1 style="color:#0b2b4a; border-bottom: 4px solid #2a7de1; padding-bottom: 8px; display:flex; align-items:center; gap:10px;">
# Representación de un problema mediante estados
# </h1>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Parte A: Ficha del problema</h2>
#
# <div style="background:#f0f7ff; border-left:6px solid #2a7de1; padding:16px 20px; border-radius:0 12px 12px 0; box-shadow: 0 2px 8px rgba(42,125,225,0.08); margin-bottom:20px;">
#   <p style="margin:0; color:#1a3b5c;">
#     <b>Caso:</b> Un repartidor debe ir desde el <b>Almacén</b> hasta la <b>Zona Norte</b>,
#     pudiendo pasar por distintos <b>puntos intermedios</b> de la ciudad.
#   </p>
# </div>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Componente</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Descripción</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Estado inicial</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Almacén</code>
#         (punto de partida del repartidor).
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Estado objetivo</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Zona Norte</code>
#         (destino final del repartidor).
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Estados intermedios</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         Distintos puntos de la ciudad por los que puede pasar el repartidor
#         (<code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Punto A</code>,
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Punto B</code>,
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Punto C</code>,
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Punto D</code>,
#         …).
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Acciones</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">moverse de un punto a otro</span>
#         <span style="background:#fef3d6; color:#92600a; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5d98a;">elegir ruta intermedia</span>
#         <span style="background:#f0f7ff; color:#1a5ca8; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #a8cbf0;">llegar al destino</span>
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Costo</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         Distancia recorrida, tiempo de viaje o tráfico en cada tramo entre puntos de la ciudad.
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Solución</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         Secuencia de puntos intermedios que lleva al repartidor desde el
#         <b>Almacén</b> hasta la <b>Zona Norte</b> con el menor costo posible.
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Tipo de problema</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">Búsqueda en grafo</span>
#         <span style="background:#f0f7ff; color:#1a5ca8; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #a8cbf0;">Búsqueda de camino óptimo</span>
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# <h2 style="color:#1e4a76; margin-top:28px;">Modelado formal</h2>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Elemento</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Notación</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Descripción</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Espacio de estados</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">S = {Almacén, A, B, C, D, …, Zona Norte}</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Conjunto de todos los puntos posibles.</td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Estado inicial</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">s₀ = Almacén</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Punto de partida.</td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Estado objetivo</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">G = {Zona Norte}</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Destino final.</td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Acciones</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">A(s) = {puntos conectados directamente a s}</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Movimientos válidos desde cada punto.</td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Función de transición</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">T(s, a) = s'</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Desde <code>s</code>, aplicar <code>a</code> lleva a <code>s'</code>.</td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">Costo del camino</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">c(s, a, s') ≥ 0</code></td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Distancia / tiempo / tráfico del tramo.</td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a;">Solución</td>
#       <td style="padding:12px 16px;"><code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Almacén → … → Zona Norte</code></td>
#       <td style="padding:12px 16px;">Camino de costo mínimo entre <code>s₀</code> y <code>G</code>.</td>
#     </tr>
#   </tbody>
# </table>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h2 style="color:#1e4a76; margin-top:24px;">Parte B: Representación del mapa como grafo en python</h2>
# <div style="background:#f0f7ff; border-left:6px solid #2a7de1; padding:16px 20px; border-radius:0 12px 12px 0; box-shadow: 0 2px 8px rgba(42,125,225,0.08); margin:20px 0;">
#   <p style="margin:0; color:#1a3b5c;">
#     Se representa el mapa de la ciudad mediante un <b>diccionario de listas</b>:
#     cada <b>clave</b> es un punto de la ciudad y cada <b>valor</b> es la lista de puntos
#     conectados directamente a él.
#   </p>
# </div>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Nodos del grafo</h2>
#
# <div style="display:flex; gap:10px; flex-wrap:wrap; margin-bottom:20px;">
#   <span style="background:#d4f5e3; color:#0b6b3e; padding:6px 16px; border-radius:50px; font-weight:600; font-size:0.9em; border:1px solid #9de0bd;">Almacén</span>
#   <span style="background:#f0f7ff; color:#1a5ca8; padding:6px 16px; border-radius:50px; font-weight:600; font-size:0.9em; border:1px solid #a8cbf0;">Centro</span>
#   <span style="background:#f0f7ff; color:#1a5ca8; padding:6px 16px; border-radius:50px; font-weight:600; font-size:0.9em; border:1px solid #a8cbf0;">Terminal</span>
#   <span style="background:#f0f7ff; color:#1a5ca8; padding:6px 16px; border-radius:50px; font-weight:600; font-size:0.9em; border:1px solid #a8cbf0;">🛒 Mercado</span>
#   <span style="background:#fde0e0; color:#a12b2b; padding:6px 16px; border-radius:50px; font-weight:600; font-size:0.9em; border:1px solid #f5b3b3;">Zona Norte</span>
# </div>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Conexiones (aristas)</h2>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Punto (clave)</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Conectado con (valor)</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Grado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Almacen</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Centro, Terminal</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><b>2</b></td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Centro</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Almacen, ZonaNorte, Mercado</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><b>3</b></td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Terminal</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Almacen, Mercado</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><b>2</b></td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">Mercado</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Centro, Terminal, ZonaNorte</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;"><b>3</b></td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">ZonaNorte</code>
#       </td>
#       <td style="padding:12px 16px;">Centro, Mercado</td>
#       <td style="padding:12px 16px;"><b>2</b></td>
#     </tr>
#   </tbody>
# </table>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 20px 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h2 style="color:#1e4a76; margin:0; font-weight:600;">
# Implementación de código - gráfo
# </h2>
#
# </div>

# %%
mapa = {
    "Almacen":   ["Centro", "Terminal"],
    "Centro":    ["Almacen", "ZonaNorte", "Mercado"],
    "Terminal":  ["Almacen", "Mercado"],
    "Mercado":   ["Centro", "Terminal", "ZonaNorte"],
    "ZonaNorte": ["Centro", "Mercado"],
}

print(mapa)
# Out:
# {'Almacen': ['Centro', 'Terminal'], 'Centro': ['Almacen', 'ZonaNorte', 'Mercado'], 'Terminal': ['Almacen', 'Mercado'], 'Mercado': ['Centro', 'Terminal', 'ZonaNorte'], 'ZonaNorte': ['Centro', 'Mercado']}

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 24px; border-radius: 16px; color:#1a2b3c;">
# <h2 style="color:#1e4a76; margin-top:24px;">Parte C: Implementación de BFS (Búsqueda en Amplitud)</h2>
#
# <div style="background:#f0f7ff; border-left:6px solid #2a7de1; padding:16px 20px; border-radius:0 12px 12px 0; box-shadow: 0 2px 8px rgba(42,125,225,0.08); margin-bottom:20px;">
#   <p style="margin:0; color:#1a3b5c;">
#     BFS explora el grafo por <b>niveles</b>, garantizando el <b>camino más corto en número
#     de aristas</b> entre el estado inicial y el objetivo. Se implementa con una
#     <b>cola FIFO</b> (<code style="background:#eef4fc; color:#1a5ca8; padding:2px 6px; border-radius:4px;">lista.pop(0)</code>)
#     y un conjunto de <b>visitados</b> para evitar ciclos.
#   </p>
# </div>
#
# <h2 style="color:#1e4a76; margin-top:24px;">Estructuras utilizadas</h2>
#
# <table style="width:100%; border-collapse: collapse; border-radius:12px; overflow:hidden; box-shadow: 0 4px 12px rgba(0,20,50,0.08);">
#   <thead>
#     <tr style="background: linear-gradient(135deg,#1a3e64,#235a8f); color:white;">
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Estructura</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Rol</th>
#       <th style="padding:12px 16px; text-align:left; text-transform:uppercase; font-size:0.9em; letter-spacing:0.03em;">Operación clave</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">cola</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Guarda los caminos pendientes por explorar (FIFO).</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">append()</span>
#         <span style="background:#fde0e0; color:#a12b2b; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5b3b3;">pop(0)</span>
#       </td>
#     </tr>
#     <tr>
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a; border-bottom:1px solid #e6eef8;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">visitados</code>
#       </td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">Evita reprocesar nodos y caer en ciclos.</td>
#       <td style="padding:12px 16px; border-bottom:1px solid #e6eef8;">
#         <span style="background:#f0f7ff; color:#1a5ca8; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #a8cbf0;">add()</span>
#         <span style="background:#fef3d6; color:#92600a; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #f5d98a;">in</span>
#       </td>
#     </tr>
#     <tr style="background:#f7faff;">
#       <td style="padding:12px 16px; font-weight:600; color:#0b2b4a;">
#         <code style="background:#eef4fc; color:#1a5ca8; padding:2px 8px; border-radius:6px; border:1px solid #d0e0f5;">camino</code>
#       </td>
#       <td style="padding:12px 16px;">Lista ordenada de nodos desde <code>inicio</code> hasta el nodo actual.</td>
#       <td style="padding:12px 16px;">
#         <span style="background:#d4f5e3; color:#0b6b3e; padding:3px 12px; border-radius:50px; font-weight:600; font-size:0.85em; border:1px solid #9de0bd;">camino + [vecino]</span>
#       </td>
#     </tr>
#   </tbody>
# </table>
#
# <h2 style="color:#1e4a76; margin-top:28px;">Pseudocódigo</h2>
#
# <div style="background:#0f2233; color:#d6e6ff; padding:18px 22px; border-radius:12px; font-family:'JetBrains Mono','Consolas',monospace; font-size:0.92em; line-height:1.7; box-shadow: 0 4px 12px rgba(15,34,51,0.25);">
#   <span style="color:#7fb4ff;">BFS</span>(grafo, inicio, objetivo):<br>
#   &nbsp;&nbsp;cola ← [[inicio]]<br>
#   &nbsp;&nbsp;visitados ← ∅<br>
#   &nbsp;&nbsp;<span style="color:#7fb4ff;">mientras</span> cola ≠ ∅:<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;camino ← cola.<span style="color:#9de0bd;">pop(0)</span><br>
#   &nbsp;&nbsp;&nbsp;&nbsp;nodo_actual ← camino[-1]<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#7fb4ff;">si</span> nodo_actual = objetivo: <span style="color:#7fb4ff;">retornar</span> camino<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#7fb4ff;">si</span> nodo_actual ∉ visitados:<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;visitados.<span style="color:#9de0bd;">add</span>(nodo_actual)<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<span style="color:#7fb4ff;">para</span> vecino en grafo[nodo_actual]:<br>
#   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;cola.<span style="color:#9de0bd;">append</span>(camino + [vecino])<br>
#   &nbsp;&nbsp;<span style="color:#7fb4ff;">retornar</span> None
# </div>
#
# </div>

# %% [markdown]
# <div style="font-family: 'Segoe UI', Roboto, Arial, sans-serif; background: linear-gradient(135deg,#e8f0fe 0%,#f3f7fb 100%); padding: 20px 24px; border-radius: 16px; color:#1a2b3c;">
#
# <h2 style="color:#1e4a76; margin:0; font-weight:600;">
# Implementación de código - Búsqueda en amplitud (BFS)
# </h2>
#
# </div>

# %%
def bfs(grafo, inicio, objetivo):
    """
    Busca el camino más corto entre 'inicio' y 'objetivo' usando BFS.
    """
    cola = [[inicio]]         
    visitados = set()

    while cola:
        camino = cola.pop(0)   # sacar el primer camino de la cola (FIFO)
        nodo_actual = camino[-1]

        if nodo_actual == objetivo:
            return camino

        if nodo_actual not in visitados:
            visitados.add(nodo_actual)

            for vecino in grafo[nodo_actual]:
                # Crear un nuevo camino = camino actual + vecino
                nuevo_camino = camino + [vecino]
                cola.append(nuevo_camino)

    return None  # no se encontró un camino


# --- Ejecución sobre el mapa de la ciudad ---
resultado = bfs(mapa, "Almacen", "ZonaNorte")
print("Camino encontrado:", resultado)
# Out:
# Camino encontrado: ['Almacen', 'Centro', 'ZonaNorte']
